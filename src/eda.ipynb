# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
sns.set()

# %%
data = pd.read_csv("../data/merged_data.csv")

# %%
data.columns
# Out:
# Index(['Season_End_Year', 'Squad', 'Comp', 'Player', 'Nation', 'Pos', 'Age',
#        'Born', 'MP_Playing', 'Starts_Playing', 'Min_Playing',
#        'Mins_Per_90_Playing', 'Gls', 'Ast', 'G_minus_PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'Gls_Per', 'Ast_Per', 'G+A_Per', 'G_minus_PK_Per',
#        'G+A_minus_PK_Per', 'Url', 'xG_Expected', 'npxG_Expected',
#        'xA_Expected', 'npxG+xA_Expected', 'xG_Per', 'xA_Per', 'xG+xA_Per',
#        'npxG_Per', 'npxG+xA_Per', 'BO_JK', 'Nom', 'Pays', 'Club', '%',
#        'UCL_JK', 'won_UCL', 'Squad_JK', 'Nation_JK', 'winner_Bundesliga',
#        'winner_C3', 'finalist_C3', 'winner_UCL', 'finalist_UCL',
#        'winner_Club WC', 'finalist_Club WC', 'winner_Copa America',
#        'finalist_Copa America', 'winner_Euro', 'finalist_Euro', 'winner_Liga',
#        'winner_Ligue 1', 'winner_PL', 'winner_Serie A', 'winner_WC',
#        'finalist_WC'],
#       dtype='object')

# %%
profile = ProfileReport(data, explorative=True, title="Pandas Profiling Report")
profile.to_file("profile.html")

# %%
df = data[['Season_End_Year', 'Squad', 'Comp', 'Player', 'Nation', 'Pos', 'Age',
       'Born', 'MP_Playing', 'Starts_Playing', 'Min_Playing',
       'Mins_Per_90_Playing', 'Gls', 'Ast', 'G_minus_PK', 'PK', 'PKatt',
       'CrdY', 'CrdR', 'Gls_Per', 'Ast_Per', 'G+A_Per', 'G_minus_PK_Per',
       'G+A_minus_PK_Per', 'winner_Bundesliga',
       'winner_C3', 'finalist_C3', 'winner_UCL', 'finalist_UCL',
       'winner_Club WC', 'finalist_Club WC', 'winner_Copa America',
       'finalist_Copa America', 'winner_Euro', 'finalist_Euro', 'winner_Liga',
       'winner_Ligue 1', 'winner_PL', 'winner_Serie A', 'winner_WC',
       'finalist_WC','%','Rang']]

# %%
global_data = df[['Season_End_Year', 'Squad', 'Comp', 'Player', 'Nation', 'Pos', 'Age',
       'Born', 'MP_Playing', 'Starts_Playing', 'Min_Playing', 'Gls', 'Ast', 'G_minus_PK', 'PK', 'PKatt',
       'CrdY', 'CrdR','winner_Bundesliga',
       'winner_C3', 'finalist_C3', 'winner_UCL', 'finalist_UCL',
       'winner_Club WC', 'finalist_Club WC', 'winner_Copa America',
       'finalist_Copa America', 'winner_Euro', 'finalist_Euro', 'winner_Liga',
       'winner_Ligue 1', 'winner_PL', 'winner_Serie A', 'winner_WC',
       'finalist_WC','%','Rang']]

# %%
data_per_90_minutes = df[['Season_End_Year', 'Squad', 'Comp', 'Player', 'Nation', 'Pos', 'Age',
       'Born','Mins_Per_90_Playing','CrdY', 'CrdR', 'Gls_Per', 'Ast_Per', 'G+A_Per', 'G_minus_PK_Per',
       'G+A_minus_PK_Per', 'winner_Bundesliga',
       'winner_C3', 'finalist_C3', 'winner_UCL', 'finalist_UCL',
       'winner_Club WC', 'finalist_Club WC', 'winner_Copa America',
       'finalist_Copa America', 'winner_Euro', 'finalist_Euro', 'winner_Liga',
       'winner_Ligue 1', 'winner_PL', 'winner_Serie A', 'winner_WC',
       'finalist_WC','%','Rang']]

# %%
profile_global_data = ProfileReport(global_data, explorative=True)
profile_global_data.to_file("../data/global_data.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 166.76it/s]

# %%
global_data.profile_report(correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": True},
        "phi_k": {"calculate": True},
        "cramers": {"calculate": True},
    },)
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-11-29 19:23:21.121367&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
global_data["%"].unique()
# Out:
# array(['13.986928104575163', '9.019607843137255', '7.8431372549019605',
#        '18.823529411764707', '4.967320261437909', '2.8758169934640523',
#        '2.6143790849673203', '1.6993464052287581', '1.5686274509803921',
#        '1.1764705882352942', '1.0457516339869282', '0.5228758169934641',
#        '0.39215686274509803', '0.13071895424836602', '29.019607843137255',
#        '8.235294117647058', '7.450980392156863', '6.143790849673203',
#        '5.228758169934641', '4.57516339869281', '2.4836601307189543',
#        '2.0915032679738563', '1.9607843137254901', '1.8300653594771241',
#        '1.4379084967320261', '1.3071895424836601', '0.9150326797385621',
#        '0.7843137254901961', '0.6535947712418301', '0.26143790849673204',
#        '31.895424836601308', '8.88888888888889', '8.627450980392156',
#        '6.666666666666667', '5.882352941176471', '5.620915032679738',
#        '4.705882352941177', '3.6601307189542482', '28.627450980392158',
# ...

# %%
global_data['%'].dropna(inplace=True)
global_data['%'] = global_data['%'].astype(float)
# Out:
# C:\Users\charl\miniconda3\envs\BallondOr\lib\site-packages\pandas\core\series.py:5258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)
# C:\Users\charl\AppData\Local\Temp/ipykernel_5836/333043673.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_data['%'] = global_data['%'].astype(float)

# %%
sns.regplot(x="Age",y="%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7744/2897639110.py in <module>
# ----> 1 sns.regplot(x="Age",y="%")
#
# ~\miniconda3\envs\BallondOr\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\miniconda3\envs\BallondOr\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     849 ):
#     850
# --> 851     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
# ...

# %%
global_data[global_data["Gls"]>25][["Player","Gls","%"]]
# Out:
#               Player   Gls          %
# 0       Alan Shearer  31.0  13.986928
# 4       Alan Shearer  31.0  13.986928
# 22           Ronaldo  34.0  29.019608
# 73   Oliver Bierhoff  27.0   1.176471
# 148    Hernán Crespo  26.0   0.392157
# ..               ...   ...        ...
# 570    Mohamed Salah  32.0   6.527778
# 574       Harry Kane  30.0   0.868056
# 585   Edinson Cavani  28.0   0.104167
# 594     Lionel Messi  36.0  24.360795
# 599    Kylian Mbappé  33.0   3.160511
#
# [61 rows x 3 columns]

# %%
global_data['%'].unique()
# Out:
# array([1.39869281e+01, 9.01960784e+00, 7.84313725e+00, 1.88235294e+01,
#        4.96732026e+00, 2.87581699e+00, 2.61437908e+00, 1.69934641e+00,
#        1.56862745e+00, 1.17647059e+00, 1.04575163e+00, 5.22875817e-01,
#        3.92156863e-01, 1.30718954e-01, 2.90196078e+01, 8.23529412e+00,
#        7.45098039e+00, 6.14379085e+00, 5.22875817e+00, 4.57516340e+00,
#        2.48366013e+00, 2.09150327e+00, 1.96078431e+00, 1.83006536e+00,
#        1.43790850e+00, 1.30718954e+00, 9.15032680e-01, 7.84313725e-01,
#        6.53594771e-01, 2.61437908e-01, 3.18954248e+01, 8.88888889e+00,
#        8.62745098e+00, 6.66666667e+00, 5.88235294e+00, 5.62091503e+00,
#        4.70588235e+00, 3.66013072e+00, 2.86274510e+01, 2.01307190e+01,
#        6.27450980e+00, 4.31372549e+00, 3.92156863e+00, 3.52941176e+00,
#        2.57516340e+01, 2.36601307e+01, 5.09803922e+00, 3.39869281e+00,
#        2.30065359e+01, 1.83006536e+01, 1.49019608e+01, 1.33333333e+01,
# ...

# %%
sns.histplot(data=global_data,x="%")
# Out:
# <AxesSubplot:xlabel='%', ylabel='Count'>

# %%
test = global_data[global_data['%'] > 7]
test.dropna(axis=0,subset=["%",'Ast'],inplace=True)
# Out:
# C:\Users\charl\miniconda3\envs\BallondOr\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
test['%'].describe()
# Out:
# count    46.000000
# mean     23.923527
# std       8.459279
# min      15.512821
# 25%      17.454583
# 50%      21.923077
# 75%      27.430408
# max      47.880000
# Name: %, dtype: float64

# %%
sns.histplot(data=test,x="%")
# Out:
# <AxesSubplot:xlabel='%', ylabel='Count'>

# %%
sns.regplot(x=(test['Ast']-test['Ast'].mean())/test['Ast'].std(),y=test['%'])
# Out:
# <AxesSubplot:xlabel='Ast', ylabel='%'>

# %%
sns.regplot(data=test,x='Gls',y='Ast')
# Out:
# <AxesSubplot:xlabel='Gls', ylabel='Ast'>

# %%
test = global_data[global_data["Rang"] <= 3]
test.dropna(axis=0,subset=["%",'Ast'],inplace=True)
# Out:
# C:\Users\charl\miniconda3\envs\BallondOr\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
X = test[['Age', 'Min_Playing', 'Gls', 'Ast',
       'CrdY', 'CrdR','winner_Bundesliga',
       'winner_C3', 'finalist_C3', 'winner_UCL', 'finalist_UCL',
       'winner_Club WC', 'finalist_Club WC', 'winner_Copa America',
       'finalist_Copa America', 'winner_Euro', 'finalist_Euro', 'winner_Liga',
       'winner_Ligue 1', 'winner_PL', 'winner_Serie A', 'winner_WC',
       'finalist_WC']]
y = test[['%']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

model = cross_val_score(LinearRegression(), X_train, y_train, cv=10,scoring='neg_root_mean_squared_error')

# %%
model
# Out:
# array([ -5.15017591,  -8.1056651 ,  -5.76186513,  -3.87246922,
#        -16.16206966, -11.09330884,  -2.6420731 ,  -7.66491011,
#         -6.89845213, -13.50496181])

# %%
print("Validation RMSE : "+str(abs(model.mean()))+ " ("+str(abs(model.mean()*100/y_train['%'].mean()))+"% of the mean)")
# Out:
# Validation RMSE : 8.08559510161512 (37.513528362958944% of the mean)

# %%
from sklearn.model_selection import learning_curve

N, train_score, val_score = learning_curve(LinearRegression(), X_train,y_train, train_sizes=np.linspace(0.1,1,10),cv=10,scoring='neg_root_mean_squared_error')
print(N)
plt.plot(N[2:], abs(train_score.mean(axis=1)[2:]),label="train")
plt.plot(N[2:], abs(val_score.mean(axis=1)[2:]), label="validation")
plt.xlabel('train_sizes')
plt.legend()
# Out:
# [ 33  66  99 132 165 198 231 264 297 331]

# %%
from sklearn.linear_model import Ridge
N, train_score, val_score = learning_curve(Ridge(alpha=10), X_train,y_train, train_sizes=np.linspace(0.1,1,10),cv=10,scoring='neg_root_mean_squared_error')
print(N)
plt.plot(N[0:], abs(train_score.mean(axis=1)[0:]),label="train")
plt.plot(N[0:], abs(val_score.mean(axis=1)[0:]), label="validation")
plt.xlabel('train_sizes')
plt.legend()
# Out:
# [ 33  66  99 132 165 198 231 264 297 331]

# %%
test = data[data['Rang'] <=3]
test.dropna(axis=0,subset=["%",'Ast'],inplace=True)
# Out:
# C:\Users\charl\miniconda3\envs\BallondOr\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
test.columns
# Out:
# Index(['Season_End_Year', 'Squad', 'Comp', 'Player', 'Nation', 'Pos', 'Age',
#        'Born', 'MP_Playing', 'Starts_Playing', 'Min_Playing',
#        'Mins_Per_90_Playing', 'Gls', 'Ast', 'G_minus_PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'Gls_Per', 'Ast_Per', 'G+A_Per', 'G_minus_PK_Per',
#        'G+A_minus_PK_Per', 'Url', 'xG_Expected', 'npxG_Expected',
#        'xA_Expected', 'npxG+xA_Expected', 'xG_Per', 'xA_Per', 'xG+xA_Per',
#        'npxG_Per', 'npxG+xA_Per', 'BO_JK', 'Rang', 'Nom', 'Pays', 'Club', '%',
#        'Squad_JK', 'Nation_JK', 'winner_Bundesliga', 'winner_C3',
#        'finalist_C3', 'winner_UCL', 'finalist_UCL', 'winner_Club WC',
#        'finalist_Club WC', 'winner_Copa America', 'finalist_Copa America',
#        'winner_Euro', 'finalist_Euro', 'winner_Liga', 'winner_Ligue 1',
#        'winner_PL', 'winner_Serie A', 'winner_WC', 'finalist_WC'],
#       dtype='object')

# %%
sns.scatterplot(data=test,x="Gls",y="Ast",hue="Rang",palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Gls', ylabel='Ast'>
